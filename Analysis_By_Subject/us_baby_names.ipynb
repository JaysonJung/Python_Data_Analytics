# %% [markdown]
# # 1880~2010년의 미국 아기 이름 분석
#
# * 특정 이름의 빈도 변화를 그래프로 표시
# * 각 이름의 상대적인 등수 결정
# * 매년 가장 인기있던 이름과 가장 큰 증감률을 보인 이름
# * 이름 유행 분석 등

# %% [markdown]
# ## 데이터 로드

# %%
# 필요 라이브러리 임포트
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns
import scipy.stats as stats
# Jupyter Notebook에서 Matplotlib 출력을 위한 설정
# %matplotlib inline
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# Matplotlib 출력 크기 설정
plt.rcParams["figure.figsize"] = (14,4)
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['lines.color'] = 'r'
plt.rcParams['axes.grid'] = True

# %%
names1880 = pd.read_csv('data/names/yob1880.txt', names=['name', 'sex', 'births'])

# %%
names1880
# Out:
#            name sex  births
# 0          Mary   F    7065
# 1          Anna   F    2604
# 2          Emma   F    2003
# 3     Elizabeth   F    1939
# 4        Minnie   F    1746
# 5      Margaret   F    1578
# 6           Ida   F    1472
# 7         Alice   F    1414
# 8        Bertha   F    1320
# 9         Sarah   F    1288
# 10        Annie   F    1258
# 11        Clara   F    1226
# 12         Ella   F    1156
# 13     Florence   F    1063
# 14         Cora   F    1045
# 15       Martha   F    1040
# 16        Laura   F    1012
# 17       Nellie   F     995
# 18        Grace   F     982
# 19       Carrie   F     949
# 20        Maude   F     858
# 21        Mabel   F     808
# 22       Bessie   F     794
# 23       Jennie   F     793
# 24     Gertrude   F     787
# 25        Julia   F     783
# 26       Hattie   F     769
# 27        Edith   F     768
# 28       Mattie   F     704
# 29         Rose   F     700
# ...         ...  ..     ...
# 1970      Philo   M       5
# ...

# %% [markdown]
# 1880년생 이름, 성별별 숫자 확인

# %%
names1880.groupby('sex').births.sum()
# Out:
# sex
# F     90993
# M    110493
# Name: births, dtype: int64

# %% [markdown]
# 모든 연도 출생자들 로드

# %%
years = range(1880, 2011)
pieces = []
columns = ['name', 'sex', 'births']

for year in years:
    path = 'data/names/yob{}.txt'.format(year)
    frame = pd.read_csv(path, names=columns)
    frame['year'] = year
    pieces.append(frame)
    
names = pd.concat(pieces, ignore_index=True)

# %%
names
# Out:
#               name sex  births  year
# 0             Mary   F    7065  1880
# 1             Anna   F    2604  1880
# 2             Emma   F    2003  1880
# 3        Elizabeth   F    1939  1880
# 4           Minnie   F    1746  1880
# 5         Margaret   F    1578  1880
# 6              Ida   F    1472  1880
# 7            Alice   F    1414  1880
# 8           Bertha   F    1320  1880
# 9            Sarah   F    1288  1880
# 10           Annie   F    1258  1880
# 11           Clara   F    1226  1880
# 12            Ella   F    1156  1880
# 13        Florence   F    1063  1880
# 14            Cora   F    1045  1880
# 15          Martha   F    1040  1880
# 16           Laura   F    1012  1880
# 17          Nellie   F     995  1880
# 18           Grace   F     982  1880
# 19          Carrie   F     949  1880
# 20           Maude   F     858  1880
# 21           Mabel   F     808  1880
# 22          Bessie   F     794  1880
# 23          Jennie   F     793  1880
# ...

# %% [markdown]
# 모든 연도의 데이터가 다 로드되어 **names**라는 하나의 Dataframe에 저장
# 총 1,690,784개의 레코드

# %%
total_births = names.pivot_table('births', index='year', columns='sex', aggfunc=sum)

# %%
total_births
# Out:
# sex         F        M
# year
# 1880    90993   110493
# 1881    91955   100748
# 1882   107851   113687
# 1883   112322   104632
# 1884   129021   114445
# 1885   133056   107802
# 1886   144538   110785
# 1887   145983   101412
# 1888   178631   120857
# 1889   178369   110590
# 1890   190377   111026
# 1891   185486   101198
# 1892   212350   122038
# 1893   212908   112319
# 1894   222923   115775
# 1895   233632   117398
# 1896   237924   119575
# 1897   234199   112760
# 1898   258771   122703
# 1899   233022   106218
# 1900   299873   150554
# 1901   239351   106478
# 1902   264079   122660
# 1903   261976   119240
# 1904   275375   128129
# 1905   291641   132319
# 1906   295301   133159
# 1907   318558   146838
# 1908   334277   154339
# 1909   347191   163983
# ...       ...      ...
# 1981  1666833  1789568
# 1982  1692036  1812642
# 1983  1669486  1790670
# 1984  1682396  1802735
# 1985  1719450  1846162
# 1986  1714053  1839442
# 1987  1737508  1865113
# ...

# %% [markdown]
# Dataframe.pivot_table를 이용한 요약집계, 그리고 매년 남녀 출생수(births)를 시각화

# %%
total_births.plot(title='Total births by sex and year')

# %% [markdown]
# 매년 남녀 출생수 현황
# 1930년 이전에는 여자가 많았는데, 그 이후에 남자가 많아짐
# 각 레코드에 "prop" 컬럼을 만들고, 해당 이름의 빈도 추가

# %%
def add_prop(group):
    #births = group.births.astype(float)
    group['prop'] = group.births / group.births.sum()
    return group

names = names.groupby(['year', 'sex']).apply(add_prop)

# %%
names
# Out:
#               name sex  births  year      prop
# 0             Mary   F    7065  1880  0.077643
# 1             Anna   F    2604  1880  0.028618
# 2             Emma   F    2003  1880  0.022013
# 3        Elizabeth   F    1939  1880  0.021309
# 4           Minnie   F    1746  1880  0.019188
# 5         Margaret   F    1578  1880  0.017342
# 6              Ida   F    1472  1880  0.016177
# 7            Alice   F    1414  1880  0.015540
# 8           Bertha   F    1320  1880  0.014507
# 9            Sarah   F    1288  1880  0.014155
# 10           Annie   F    1258  1880  0.013825
# 11           Clara   F    1226  1880  0.013474
# 12            Ella   F    1156  1880  0.012704
# 13        Florence   F    1063  1880  0.011682
# 14            Cora   F    1045  1880  0.011484
# 15          Martha   F    1040  1880  0.011429
# 16           Laura   F    1012  1880  0.011122
# 17          Nellie   F     995  1880  0.010935
# 18           Grace   F     982  1880  0.010792
# ...

# %% [markdown]
# 해당 연도, 성별을 그룹으로 하고, 그 그룹에서의 이름 빈도가 추가되었다. 이 빈도가 정확하게 계산되었는지 궁금하다. 한번 확인해보자.

# %%
import numpy as np
np.allclose(names.groupby(['year', 'sex']).prop.sum(), 1)
# Out:
# True

# %% [markdown]
# 오케이. 이제부터 매년, 각 성별별로 특정 이름의 빈도 변화를 살펴보자. 매년, 각 성별별(그룹별)로 데이터수가 다르니, 그룹별 top1000만 쓰기로 하자.

# %%
def get_top1000(group):
    return group.sort_values(by='births', ascending=False)[:1000]

grouped = names.groupby(['year', 'sex'])
top1000 = grouped.apply(get_top1000)

# %%
top1000
# Out:
#                        name sex  births  year      prop
# year sex
# 1880 F   0             Mary   F    7065  1880  0.077643
#          1             Anna   F    2604  1880  0.028618
#          2             Emma   F    2003  1880  0.022013
#          3        Elizabeth   F    1939  1880  0.021309
#          4           Minnie   F    1746  1880  0.019188
#          5         Margaret   F    1578  1880  0.017342
#          6              Ida   F    1472  1880  0.016177
#          7            Alice   F    1414  1880  0.015540
#          8           Bertha   F    1320  1880  0.014507
#          9            Sarah   F    1288  1880  0.014155
#          10           Annie   F    1258  1880  0.013825
#          11           Clara   F    1226  1880  0.013474
#          12            Ella   F    1156  1880  0.012704
#          13        Florence   F    1063  1880  0.011682
#          14            Cora   F    1045  1880  0.011484
#          15          Martha   F    1040  1880  0.011429
# ...

# %% [markdown]
# top1000 변수에 그룹별 1000개의 이름 저장
#
# ## 이름 유행 분석
#
# 이름 유행 분석 -> top1000을 boys, girls로 분리

# %%
boys = top1000[top1000.sex == 'M']
girls = top1000[top1000.sex == 'F']

# %% [markdown]
# top1000을 피벗테이블로 구성

# %%
total_births = top1000.pivot_table('births', index='year', columns='name', aggfunc=sum)
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py:82: FutureWarning: 'year' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   grouped = data.groupby(keys, observed=dropna)

# %%
total_births
# Out:
# name   Aaden  Aaliyah  Aarav    Aaron  Aarush   Ab  Abagail  Abb  Abbey  \
# year
# 1880     NaN      NaN    NaN    102.0     NaN  NaN      NaN  NaN    NaN
# 1881     NaN      NaN    NaN     94.0     NaN  NaN      NaN  NaN    NaN
# 1882     NaN      NaN    NaN     85.0     NaN  NaN      NaN  NaN    NaN
# 1883     NaN      NaN    NaN    105.0     NaN  NaN      NaN  NaN    NaN
# 1884     NaN      NaN    NaN     97.0     NaN  NaN      NaN  NaN    NaN
# 1885     NaN      NaN    NaN     88.0     NaN  6.0      NaN  NaN    NaN
# 1886     NaN      NaN    NaN     86.0     NaN  NaN      NaN  NaN    NaN
# 1887     NaN      NaN    NaN     78.0     NaN  NaN      NaN  NaN    NaN
# 1888     NaN      NaN    NaN     90.0     NaN  NaN      NaN  NaN    NaN
# 1889     NaN      NaN    NaN     85.0     NaN  NaN      NaN  NaN    NaN
# 1890     NaN      NaN    NaN     96.0     NaN  NaN      NaN  6.0    NaN
# 1891     NaN      NaN    NaN     69.0     NaN  NaN      NaN  NaN    NaN
# ...

# %% [markdown]
# 이름이 너무 많으니, 관심있는 이름 John, Harry, Mary, Marilyn만 확인해보자.

# %%
subset = total_births[['John', 'Harry', 'Mary', 'Marilyn']]

# %% [markdown]
# 이 4명을 차트로 표시해보면,

# %%
subset.plot(subplots=True, figsize=(12, 10), grid=False, title='Number of births per year')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000000252E7DD8>,
# ...
#       dtype=object)

# %% [markdown]
# 각 이름별로 매년 어떻게 변화하는지 한눈에 확인 가능

# %% [markdown]
# ## 이름 다양성 증가 확인
#
# 일반적인(Top 1000) 이름 사용의 감소?

# %%
table = top1000.pivot_table('prop', index='year', columns='sex', aggfunc=sum)
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py:82: FutureWarning: 'year' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   grouped = data.groupby(keys, observed=dropna)
# C:\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py:82: FutureWarning: 'sex' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   grouped = data.groupby(keys, observed=dropna)

# %%
table
# Out:
# sex          F         M
# year
# 1880  1.000000  0.997375
# 1881  1.000000  1.000000
# 1882  0.998702  0.995646
# 1883  0.997596  0.998566
# 1884  0.993156  0.994539
# 1885  0.992251  0.995501
# 1886  0.989504  0.995035
# 1887  0.988279  0.996697
# 1888  0.984241  0.992429
# 1889  0.984061  0.994981
# 1890  0.982566  0.992749
# 1891  0.982177  0.993725
# 1892  0.979746  0.988815
# 1893  0.980001  0.991720
# 1894  0.978571  0.989048
# 1895  0.975479  0.989071
# 1896  0.975660  0.988041
# 1897  0.976558  0.989349
# 1898  0.972806  0.987197
# 1899  0.975170  0.990115
# 1900  0.967760  0.979702
# 1901  0.972304  0.989603
# 1902  0.970467  0.985749
# 1903  0.969490  0.986020
# 1904  0.968142  0.982502
# 1905  0.967038  0.981650
# 1906  0.967535  0.981759
# 1907  0.964942  0.976975
# 1908  0.964500  0.976409
# 1909  0.962744  0.973412
# ...        ...       ...
# 1981  0.867232  0.944762
# 1982  0.868208  0.944435
# 1983  0.871602  0.945170
# 1984  0.870201  0.944705
# ...

# %%
table.plot(title='Sum of table1000.prop by year and sex', yticks=np.linspace(0, 1.2, 13), xticks=range(1880, 2020, 10))

# %% [markdown]
# 그룹별 1000개 레코드의 이름빈도의 합계가 시간이 지날수록 1에서 멀어지는 걸 보아, 다양성이 증가하고 있음을 유추
# 또 다른 계산방법으로, 이름빈도로 정렬했을 때, 50%에 도달할 때, 몇명이 있는지 확인할 수 있음

# %%
df = boys[boys.year == 2010]

# %%
df
# Out:
#                          name sex  births  year      prop
# year sex
# 2010 M   1676644        Jacob   M   21875  2010  0.011523
#          1676645        Ethan   M   17866  2010  0.009411
#          1676646      Michael   M   17133  2010  0.009025
#          1676647       Jayden   M   17030  2010  0.008971
#          1676648      William   M   16870  2010  0.008887
#          1676649    Alexander   M   16634  2010  0.008762
#          1676650         Noah   M   16281  2010  0.008576
#          1676651       Daniel   M   15679  2010  0.008259
#          1676652        Aiden   M   15403  2010  0.008114
#          1676653      Anthony   M   15364  2010  0.008093
#          1676654       Joshua   M   15238  2010  0.008027
#          1676655        Mason   M   14728  2010  0.007758
#          1676656  Christopher   M   14135  2010  0.007446
#          1676657       Andrew   M   14093  2010  0.007424
#          1676658        David   M   14042  2010  0.007397
# ...

# %%
prop_cumsum = df.sort_values(by='prop', ascending=False).prop.cumsum()

# %%
prop_cumsum
# Out:
# year  sex
# 2010  M    1676644    0.011523
#            1676645    0.020934
#            1676646    0.029959
#            1676647    0.038930
#            1676648    0.047817
#            1676649    0.056579
#            1676650    0.065155
#            1676651    0.073414
#            1676652    0.081528
#            1676653    0.089621
#            1676654    0.097648
#            1676655    0.105406
#            1676656    0.112852
#            1676657    0.120276
#            1676658    0.127672
#            1676659    0.135023
#            1676660    0.142368
#            1676661    0.149603
#            1676662    0.156827
#            1676663    0.164021
#            1676664    0.170722
#            1676665    0.177191
#            1676666    0.183452
#            1676667    0.189655
#            1676668    0.195815
#            1676669    0.201832
#            1676670    0.207769
#            1676671    0.213578
#            1676672    0.219354
# ...

# %% [markdown]
# cumsum 메쏘드는 누적합을 의미한다. 위 데이터에서 0.5에 도달할 때의 index는 searchsorted 메쏘드로 확인

# %%
prop_cumsum.searchsorted(0.5)
# Out:
# array([116], dtype=int64)

# %% [markdown]
# 파이썬이 0부터 카운팅하므로, 117개의 이름이 50%를 차지함을 알 수 있다. 반면에,

# %%
df = boys[boys.year == 1900]
in1900 = df.sort_values(by='prop', ascending=False).prop.cumsum()
in1900.searchsorted(0.5) + 1
# Out:
# array([25], dtype=int64)

# %% [markdown]
# 1900년생은 25명이다. 확실히 다양성이 증가했다.
#
# 이를 종합하여 매년 어떻게 변화하는지 살펴보자.

# %%
def get_quantile_count(group, q=0.5):
    group = group.sort_values(by='prop', ascending=False)
    return (group.prop.cumsum().searchsorted(q) + 1)[0]

diversity = top1000.groupby(['year', 'sex']).apply(get_quantile_count)
diversity = diversity.unstack('sex')
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: 'year' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   """
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: 'sex' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   """

# %%
diversity
# Out:
# sex     F    M
# year
# 1880   38   14
# 1881   38   14
# 1882   38   15
# 1883   39   15
# 1884   39   16
# 1885   40   16
# 1886   41   16
# 1887   41   17
# 1888   42   17
# 1889   43   18
# 1890   44   19
# 1891   44   20
# 1892   44   20
# 1893   44   21
# 1894   45   22
# 1895   46   22
# 1896   46   23
# 1897   46   23
# 1898   47   24
# 1899   47   25
# 1900   49   25
# 1901   49   25
# 1902   49   26
# 1903   49   27
# 1904   50   28
# 1905   50   28
# 1906   49   28
# 1907   50   30
# 1908   49   30
# 1909   49   30
# ...   ...  ...
# 1981   78   35
# 1982   75   35
# 1983   71   34
# 1984   71   35
# 1985   72   36
# 1986   74   37
# 1987   75   39
# 1988   78   40
# 1989   83   43
# 1990   90   45
# 1991   95   48
# 1992  102   51
# 1993  107   54
# 1994  111   57
# 1995  115   60
# 1996  122   64
# 1997  129   67
# 1998  138   70
# 1999  146   73
# 2000  155   77
# 2001  164   81
# 2002  170   83
# 2003  178   87
# 2004  191   92
# 2005  199   96
# 2006  209   99
# ...

# %%
diversity.plot(title="Number of popular names in top 50%")

# %% [markdown]
# 남자이름 보단 여자이름이 더 다양한 것으로 나옴. 1980년대 이후 특히 증가
#
# ### 이름의 마지막 글자?
#
# 2007년에 출생아 이름 연구가 Laura Wattenberg는 남자이름의 마지막 글자 분포가 지난 100년에 걸처 유의하게 변해왔다고 주장함.

# %%
get_last_letter = lambda x: x[-1]
last_letters = names.name.map(get_last_letter)
last_letters.name = 'last_letter'
last_letters
# Out:
# 0          y
# 1          a
# 2          a
# 3          h
# 4          e
# 5          t
# 6          a
# 7          e
# 8          a
# 9          h
# 10         e
# 11         a
# 12         a
# 13         e
# 14         a
# 15         a
# 16         a
# 17         e
# 18         e
# 19         e
# 20         e
# 21         l
# 22         e
# 23         e
# 24         e
# 25         a
# 26         e
# 27         h
# 28         e
# 29         e
#           ..
# 1690754    n
# 1690755    n
# 1690756    n
# 1690757    n
# 1690758    l
# 1690759    n
# 1690760    a
# 1690761    o
# 1690762    h
# 1690763    i
# 1690764    h
# 1690765    n
# 1690766    r
# 1690767    n
# 1690768    n
# 1690769    n
# 1690770    n
# 1690771    i
# 1690772    n
# 1690773    b
# 1690774    e
# 1690775    t
# 1690776    n
# 1690777    r
# 1690778    n
# 1690779    e
# 1690780    e
# 1690781    s
# 1690782    n
# 1690783    x
# Name: last_letter, Length: 1690784, dtype: object

# %%
table = names.pivot_table('births', index=last_letters, columns=['sex', 'year'], aggfunc=sum)
table
# Out:
# sex                F                                                        \
# year            1880     1881     1882     1883     1884     1885     1886
# last_letter
# a            31446.0  31581.0  36536.0  38330.0  43680.0  45408.0  49100.0
# b                NaN      NaN      NaN      NaN      NaN      NaN      NaN
# c                NaN      NaN      5.0      5.0      NaN      NaN      NaN
# d              609.0    607.0    734.0    810.0    916.0    862.0   1007.0
# e            33378.0  34080.0  40399.0  41914.0  48089.0  49616.0  53884.0
# f                NaN      NaN      NaN      NaN      NaN      NaN      NaN
# g                7.0      5.0     12.0      8.0     24.0     11.0     18.0
# h             4863.0   4784.0   5567.0   5701.0   6602.0   6624.0   7146.0
# i               61.0     78.0     81.0     76.0     84.0     92.0     85.0
# j                NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...

# %% [markdown]
# 3개의 연도만 확인

# %%
subtable = table.reindex(columns=[1910, 1960, 2010], level='year')

# %%
subtable.sum()
# Out:
# sex  year
# F    1910     396416.0
#      1960    2022062.0
#      2010    1759010.0
# M    1910     194198.0
#      1960    2132588.0
#      2010    1898382.0
# dtype: float64

# %%
letter_prop = subtable / subtable.sum()

# %%
letter_prop
# Out:
# sex                 F                             M
# year             1910      1960      2010      1910      1960      2010
# last_letter
# a            0.273390  0.341853  0.381240  0.005031  0.002440  0.014980
# b                 NaN  0.000343  0.000256  0.002116  0.001834  0.020470
# c            0.000013  0.000024  0.000538  0.002482  0.007257  0.012181
# d            0.017028  0.001844  0.001482  0.113858  0.122908  0.023387
# e            0.336941  0.215133  0.178415  0.147556  0.083853  0.067959
# f                 NaN  0.000010  0.000055  0.000783  0.004325  0.001188
# g            0.000144  0.000157  0.000374  0.002250  0.009488  0.001404
# h            0.051529  0.036224  0.075852  0.045562  0.037907  0.051670
# i            0.001526  0.039965  0.031734  0.000844  0.000603  0.022628
# j                 NaN       NaN  0.000090       NaN       NaN  0.000769
# k            0.000121  0.000156  0.000356  0.036581  0.049384  0.018541
# ...

# %% [markdown]
# 이를 차트로 표시해보면,

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 1, figsize=(12,8))
letter_prop['M'].plot(kind='bar', rot=0, ax=axes[0], title='Male')
letter_prop['F'].plot(kind='bar', rot=0, ax=axes[1], title='Female', legend=False)

# %% [markdown]
# 남자의 경우, 1960년대 이후, "n"으로 끝나는 이름이 현저히 늘었다. 이를 전체 그룹에 대해 확장해보자.

# %%
letter_prop = table / table.sum()
dny_ts = letter_prop.ix[['d', 'n', 'y'], 'M'].T
dny_ts
# Out:
# C:\Users\jayhu\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
# last_letter         d         n         y
# year
# 1880         0.083055  0.153213  0.075760
# 1881         0.083247  0.153214  0.077451
# 1882         0.085340  0.149560  0.077537
# 1883         0.084066  0.151646  0.079144
# 1884         0.086120  0.149915  0.080405
# 1885         0.085472  0.146361  0.081882
# 1886         0.087647  0.149659  0.081681
# 1887         0.089072  0.148838  0.082870
# 1888         0.087707  0.151286  0.084919
# 1889         0.091934  0.151976  0.086328
# 1890         0.093834  0.146470  0.086277
# 1891         0.094478  0.148353  0.084933
# 1892         0.096388  0.144857  0.084883
# 1893         0.098318  0.142558  0.084643
# ...

# %% [markdown]
# 이를 차트로 표시하면,

# %%
dny_ts.plot()

# %% [markdown]
# 전체 연도로 패턴을 보니, 확실히 "n"으로 끝나는 빈도 증가
#
# ## 성별이 바뀌는 이름
#
# 성별이 바뀌는 이름 존재
# Lesley, Leslie 이름이 대표적인 예. 이를 구체적으로 확인

# %%
all_names = top1000.name.unique()
mask = np.array(['lesl' in x.lower() for x in all_names])
lesley_like = all_names[mask]
lesley_like
# Out:
# array(['Leslie', 'Lesley', 'Leslee', 'Lesli', 'Lesly'], dtype=object)

# %%
filtered = top1000[top1000.name.isin(lesley_like)]
filtered.groupby('name').births.sum()
# Out:
# name
# Leslee      1082
# Lesley     35022
# Lesli        929
# Leslie    370429
# Lesly      10067
# Name: births, dtype: int64

# %%
table = filtered.pivot_table('births', index='year', columns='sex', aggfunc=sum)
table
# Out:
# C:\Users\jayhu\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py:82: FutureWarning: 'year' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   grouped = data.groupby(keys, observed=dropna)
# C:\Users\jayhu\Anaconda3\lib\site-packages\pandas\core\reshape\pivot.py:82: FutureWarning: 'sex' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   grouped = data.groupby(keys, observed=dropna)
# sex        F      M
# year
# 1880     8.0   79.0
# 1881    11.0   92.0
# 1882     9.0  128.0
# 1883     7.0  125.0
# 1884    15.0  125.0
# 1885    10.0  122.0
# 1886     8.0  136.0
# 1887    12.0  166.0
# 1888    23.0  175.0
# 1889    23.0  155.0
# 1890    20.0  181.0
# 1891    28.0  164.0
# 1892    22.0  207.0
# 1893    26.0  185.0
# 1894    36.0  223.0
# 1895    22.0  235.0
# 1896    27.0  237.0
# 1897    34.0  222.0
# 1898    24.0  236.0
# ...

# %%
table = table.div(table.sum(1), axis=0)
table
# Out:
# sex          F         M
# year
# 1880  0.091954  0.908046
# 1881  0.106796  0.893204
# 1882  0.065693  0.934307
# 1883  0.053030  0.946970
# 1884  0.107143  0.892857
# 1885  0.075758  0.924242
# 1886  0.055556  0.944444
# 1887  0.067416  0.932584
# 1888  0.116162  0.883838
# 1889  0.129213  0.870787
# 1890  0.099502  0.900498
# 1891  0.145833  0.854167
# 1892  0.096070  0.903930
# 1893  0.123223  0.876777
# 1894  0.138996  0.861004
# 1895  0.085603  0.914397
# 1896  0.102273  0.897727
# 1897  0.132812  0.867188
# 1898  0.092308  0.907692
# 1899  0.090452  0.909548
# 1900  0.095238  0.904762
# 1901  0.124464  0.875536
# 1902  0.128472  0.871528
# 1903  0.089552  0.910448
# 1904  0.109890  0.890110
# 1905  0.124113  0.875887
# 1906  0.099315  0.900685
# 1907  0.110749  0.889251
# 1908  0.123867  0.876133
# 1909  0.107034  0.892966
# ...        ...       ...
# 1981  0.920584  0.079416
# 1982  0.931134  0.068866
# 1983  0.923177  0.076823
# 1984  0.923318  0.076682
# ...

# %%
table.plot(style={'M': 'k-', 'F': 'b--'})

# %% [markdown]
# "Lesl~"로 시작하는 이름은 1940년대에는 남자이름이었다가 그후 빠르게 여자이름으로 바뀜.

# %% [markdown]
# ##### End of Document
